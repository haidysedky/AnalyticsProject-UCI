# %%
import pandas as pd
import requests
import json
import time
from datetime import datetime
from pprint import pprint
from config import api_key

# %%
file1 = "Most popular 100 movies.csv"
file2 = "Cast_100_popular_movies.csv"
file3 = "Genre list.csv"
file4 = "100 popular with genre.csv"
file5= "Lead actors info.csv"

# %%
movie = pd.read_csv(file1)
cast = pd.read_csv(file2)
genre_list = pd.read_csv(file3)
movie_genre = pd.read_csv(file4)
actor_info = pd.read_csv(file5)

# %%
actor_info.head()
# Out:
#    Unnamed: 0  actor id            actor name  \
# 0           0       417      Ginnifer Goodwin
# 1           1     71580  Benedict Cumberbatch
# 2           2     16828           Chris Evans
# 3           3     31167    Elizabeth Mitchell
# 4           4     37632        Eddie Redmayne
#
#                           character  gender      id  movie release year  \
# 0                Judy Hopps (voice)  Female  269149                2016
# 1  Stephen Strange / Doctor Strange    Male  284052                2016
# 2    Steve Rogers / Captain America    Male  271110                2016
# 3              Senator Charlie Roan  Female  316727                2016
# 4                    Newt Scamander    Male  259316                2016
#
#                                      title  age  \
# 0                                 Zootopia   38
# 1                           Doctor Strange   40
# 2               Captain America: Civil War   35
# 3                 The Purge: Election Year   46
# ...

# %%
gender_grpd_cast = pop_100_cast_df.groupby("gender code")
average_age_gender = gender_grpd_cast["age"].mean()
average_age_gender
